# %% [markdown]
# ## Grille de carrés colorés avec le module BlockGrid
#
# ### Prise en main

# %%
from ipythonblocks import BlockGrid
grid = BlockGrid(10, 10, fill=(125,234,231))
grid.show()
# Out:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks52b10dd7-672b-4236-8b82-f7e008dc53e1 td {border: 1px solid white;}</style><table id="blocks52b10dd7-672b-4236-8b82-f7e008dc53e1" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (125, 234, 231)" style="width: 20px; height: 20px;background-color: rgb(125, 234, 231);"></td><td title="Index: [0, 1]&#10;Color: (125, 234, 231)" style="width: 20px; height: 20px;background-color: rgb(125, 234, 231);"></td><td title="Index: [0, 2]&#10;Color: (125, 234, 231)" style="width: 20px; height: 20px;background-color: rgb(125, 234, 231);"></td><td title="Index: [0, 3]&#10;Color: (125, 234, 231)" style="width: 20px; height: 20px;background-color: rgb(125, 234, 231);"></td><td title="Index: [0, 4]&#10;Color: (125, 234, 231)" style="width: 20px; height: 20px;background-color: rgb(125, 234, 231);"></td><td title="Index: [0, 5]&#10;Color: (125, 234, 231)" style="width: 2
# ...

# %%
grid[2,5].set_colors(0,0,0)
grid.show()
# Out:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocksa17aa750-4351-4860-926a-490db2b85f50 td {border: 1px solid white;}</style><table id="blocksa17aa750-4351-4860-926a-490db2b85f50" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (125, 234, 231)" style="width: 20px; height: 20px;background-color: rgb(125, 234, 231);"></td><td title="Index: [0, 1]&#10;Color: (125, 234, 231)" style="width: 20px; height: 20px;background-color: rgb(125, 234, 231);"></td><td title="Index: [0, 2]&#10;Color: (125, 234, 231)" style="width: 20px; height: 20px;background-color: rgb(125, 234, 231);"></td><td title="Index: [0, 3]&#10;Color: (125, 234, 231)" style="width: 20px; height: 20px;background-color: rgb(125, 234, 231);"></td><td title="Index: [0, 4]&#10;Color: (125, 234, 231)" style="width: 20px; height: 20px;background-color: rgb(125, 234, 231);"></td><td title="Index: [0, 5]&#10;Color: (125, 234, 231)" style="width: 2
# ...

# %% [markdown]
# ### Exercice 1
# Faites en sorte que la troisième colonne soit noire.

# %%
# Out:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks8818fb5b-35ee-4e2d-b563-b9568c312b5d td {border: 1px solid white;}</style><table id="blocks8818fb5b-35ee-4e2d-b563-b9568c312b5d" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (125, 234, 231)" style="width: 20px; height: 20px;background-color: rgb(125, 234, 231);"></td><td title="Index: [0, 1]&#10;Color: (125, 234, 231)" style="width: 20px; height: 20px;background-color: rgb(125, 234, 231);"></td><td title="Index: [0, 2]&#10;Color: (125, 234, 231)" style="width: 20px; height: 20px;background-color: rgb(125, 234, 231);"></td><td title="Index: [0, 3]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 4]&#10;Color: (125, 234, 231)" style="width: 20px; height: 20px;background-color: rgb(125, 234, 231);"></td><td title="Index: [0, 5]&#10;Color: (125, 234, 231)" style="width: 20px; height:
# ...

# %% [markdown]
# ###### Exercice 2
# Faites en sorte qu'une colonne sur 2 soit noire.

# %%
# Out:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks6f2833ba-193c-4045-8840-e82fa4ffe461 td {border: 1px solid white;}</style><table id="blocks6f2833ba-193c-4045-8840-e82fa4ffe461" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (125, 234, 231)" style="width: 20px; height: 20px;background-color: rgb(125, 234, 231);"></td><td title="Index: [0, 1]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 2]&#10;Color: (125, 234, 231)" style="width: 20px; height: 20px;background-color: rgb(125, 234, 231);"></td><td title="Index: [0, 3]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 4]&#10;Color: (125, 234, 231)" style="width: 20px; height: 20px;background-color: rgb(125, 234, 231);"></td><td title="Index: [0, 5]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-c
# ...

# %% [markdown]
# ### Exercice 3
# Faites en sorte qu'un damier apparaisse.

# %%
# Out:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks67f28522-ead9-4ea9-acd4-e8da69da78f7 td {border: 1px solid white;}</style><table id="blocks67f28522-ead9-4ea9-acd4-e8da69da78f7" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 1]&#10;Color: (125, 234, 231)" style="width: 20px; height: 20px;background-color: rgb(125, 234, 231);"></td><td title="Index: [0, 2]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 3]&#10;Color: (125, 234, 231)" style="width: 20px; height: 20px;background-color: rgb(125, 234, 231);"></td><td title="Index: [0, 4]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 5]&#10;Color: (125, 234, 231)" style="width: 20px; height: 20px;background-color: 
# ...

# %% [markdown]
# ### Exercice 4
# Faites en sorte qu'un escalier apparaisse

# %%
# Out:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocksce2831e2-5c62-4708-8f3c-4004a47e803b td {border: 1px solid white;}</style><table id="blocksce2831e2-5c62-4708-8f3c-4004a47e803b" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (125, 234, 231)" style="width: 20px; height: 20px;background-color: rgb(125, 234, 231);"></td><td title="Index: [0, 1]&#10;Color: (125, 234, 231)" style="width: 20px; height: 20px;background-color: rgb(125, 234, 231);"></td><td title="Index: [0, 2]&#10;Color: (125, 234, 231)" style="width: 20px; height: 20px;background-color: rgb(125, 234, 231);"></td><td title="Index: [0, 3]&#10;Color: (125, 234, 231)" style="width: 20px; height: 20px;background-color: rgb(125, 234, 231);"></td><td title="Index: [0, 4]&#10;Color: (125, 234, 231)" style="width: 20px; height: 20px;background-color: rgb(125, 234, 231);"></td><td title="Index: [0, 5]&#10;Color: (125, 234, 231)" style="width: 2
# ...
